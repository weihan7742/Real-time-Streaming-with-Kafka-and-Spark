# %% [markdown]
# ## Building a MongoDB Data Model
#
# - The relationship between climate data and fire data is one-to-many relationship. It is guaranteed that one climate data will be recorded on a daily basis regardless if there are any fire data on that particular day, and a fire data will only be connected to a single climate data by referencing on the date attribute. Therefore, the query operation will be more efficient to retrieve both the climate data and fire data.
#
# Example of the data model:
# ~~~
#
# [
#  {
#    "station":"948701",
#    "date":"6/3/21",
#    "air_temperature_celcius":20,
#    "relative_humidity":52.9,
#    "windspeed_knots":17.0,
#    "max_wind_speed":21.0,
#    "GHI_w/m2":167,
#    "precipitation_flag":"I",
#    "precipitation_value":0.0,
#    "cause_of_fire": "other",
#    "hotspot":[
#       {
#          "latitude":-34.3795,
#          "longitude":141.6331,
#          "datetime":"2021-03-06T05:06:30",
#          "confidence":87,
#          "surface_temperature_celcius":62
#       },
#       {
#          "latitude":-34.3735,
#          "longitude":141.6604,
#          "datetime":"2021-03-06T05:06:20",
#          "confidence":85,
#          "surface_temperature_celcius":59
#       }
#    ]
#  },
# ...
# ]
#
# ~~~

# %% [markdown]
# ## Querying MongoDB using PyMongo

# %%
# Import necessary libraries
import pymongo
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime
import csv

# %%
client = MongoClient()
db = client.fit3182_assignment_db
collection = db.data

# %%
# Function to parse csv to dictionary
def convert_csv_to_dict(file_path, int_list, float_list):
    reader = csv.DictReader(open(file_path,'r'))
    content = list(reader)
    
    # Iterate over each row
    for row in content:
        # Convert string to int
        for col in int_list:
            row[col] = int(row[col])
            
        # Convert string to float
        for col in float_list:
            # Separate precipitation flag from value
            if col == 'precipitation ':
                item = row[col].strip()
                flag = item[-1]
                value = float(item[:len(item)-1])
                row['precipitation_flag'] = flag
                row['precipitation_value'] = value
                
                # Remove key
                row.pop('precipitation ')
            else:
                row[col] = float(row[col])
                
    return content

# %%
# Separate columns into int list and float list
cl_int_list = ['GHI_w/m2','air_temperature_celcius']
cl_float_list = ['max_wind_speed','windspeed_knots','relative_humidity','precipitation ']

# Obtain dictionary data from climate_historic.csv
cl_dict = convert_csv_to_dict("climate_historic.csv", cl_int_list, cl_float_list)

# %%
# Separate columns into int list and float list
fr_int_list = ['confidence','surface_temperature_celcius']
fr_float_list = ['latitude','longitude']

# Obtain dictionary data from hotspot_historic.csv
fr_dict = convert_csv_to_dict("hotspot_historic.csv", fr_int_list, fr_float_list)

# %%
# Group data with the same date 
fr_join_dict = {}

for item in fr_dict:
    key = datetime.strptime(item['date'],'%d/%m/%Y').date()
    item.pop('date')
    try:
        fr_join_dict[key].append(item)
    except KeyError:
        fr_join_dict[key] = [item]

# %%
# Embed hotspot data into climate data
for item in cl_dict:
    key = datetime.strptime(item['date'],'%d/%m/%y').date()
    
    try:
        item['hotspot'] = fr_join_dict[key]
        
        # For Part B: Label cause of fire
        if item['GHI_w/m2'] > 180 and item['air_temperature_celcius'] > 20:
            item['cause_of_fire'] = 'natural'
        else:
            item['cause_of_fire'] = 'other'
    except KeyError:
        pass

# %%
collection.insert_many(cl_dict)

# %% [markdown]
# ### Q2

# %%
# Function to print document in cursor
def print_document(cursor):
    for document in cursor:
        pprint(document)

# %%
# a. Find climate data on 12th December 2021
cursor = collection.find({'date':'12/12/21'}, {'_id':0})
print_document(cursor)
# Out:
# {'GHI_w/m2': 156,
#  'air_temperature_celcius': 19,
#  'cause_of_fire': 'other',
#  'date': '12/12/21',
#  'hotspot': [{'confidence': 53,
#               'datetime': '2021-12-12T00:45:38',
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.3,
#  'station': '948702',
#  'windspeed_knots': 6.2}

# %%
# b. Find the latitude, longitude, surface temperature and confidence when
# the surface temperature was between 65 and 100.
cursor = collection.aggregate([
    {
        "$unwind": "$hotspot"
    },
    {
        "$match": {"hotspot.surface_temperature_celcius": {"$gte":65,"$lte":100}}
    },
    {
        "$project":{"hotspot.latitude":1,
                    "hotspot.longitude":1,
                    "hotspot.surface_temperature_celcius":1,
                    "hotspot.confidence":1,
                    "_id":0}
    }
])
print_document(cursor)
# Out:
# {'hotspot': {'confidence': 94,
#              'latitude': -37.2284,
#              'longitude': 147.9187,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.6572,
#              'longitude': 142.0703,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 84,
#              'latitude': -37.0193,
#              'longitude': 148.1459,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.4229,
#              'longitude': 147.027,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 80,
#              'latitude': -37.0055,
#              'longitude': 148.1582,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 85,
#              'latitude': -37.4128,
#              'longitude': 147.0242,
#              'surface_temperature_celcius': 98}}
# {'hotspot': {'confidence': 90,
#              'latitude': -34.357,
#              'longitude': 141.5361,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 93,
#              'latitude': -34.3539,
#              'longitude': 141.5547,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 90,
#              'latitude': -36.9939,
#              'longitude': 148.2244,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.9959,
#              'longitude': 148.2118,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 89,
#              'latitude': -34.3654,
#              'longitude': 141.543,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 96,
#              'latitude': -34.3554,
#              'longitude': 141.5413,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 94,
#              'latitude': -34.3555,
#              'longitude': 141.5495,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.7152,
#              'longitude': 141.3853,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.0155,
#              'longitude': 148.1432,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.6622,
#              'longitude': 142.1001,
#              'surface_temperature_celcius': 79}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.4523,
#              'longitude': 147.0175,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.4261,
#              'longitude': 147.0323,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.3949,
#              'longitude': 147.0175,
#              'surface_temperature_celcius': 91}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.6625,
#              'longitude': 144.287,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 82,
#              'latitude': -37.8973,
#              'longitude': 143.4754,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.7805,
#              'longitude': 143.5003,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8774,
#              'longitude': 145.8213,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.8881,
#              'longitude': 145.8229,
#              'surface_temperature_celcius': 99}}
# {'hotspot': {'confidence': 71,
#              'latitude': -37.522,
#              'longitude': 143.3874,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 91,
#              'latitude': -38.0674,
#              'longitude': 142.965,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 92,
#              'latitude': -38.0715,
#              'longitude': 142.9591,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 100,
#              'latitude': -38.0693,
#              'longitude': 142.9722,
#              'surface_temperature_celcius': 89}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.4557,
#              'longitude': 142.2434,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 95,
#              'latitude': -36.8009,
#              'longitude': 142.7259,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 93,
#              'latitude': -36.8099,
#              'longitude': 142.728,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 94,
#              'latitude': -36.7806,
#              'longitude': 141.5597,
#              'surface_temperature_celcius': 74}}
# {'hotspot': {'confidence': 98,
#              'latitude': -34.3526,
#              'longitude': 141.6458,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.0924,
#              'longitude': 141.897,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.9452,
#              'longitude': 143.5834,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 99,
#              'latitude': -34.351,
#              'longitude': 141.6567,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.5012,
#              'longitude': 142.5853,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.9247,
#              'longitude': 142.8999,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 97,
#              'latitude': -35.0805,
#              'longitude': 142.4642,
#              'surface_temperature_celcius': 81}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.3735,
#              'longitude': 145.886,
#              'surface_temperature_celcius': 96}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.7465,
#              'longitude': 143.3806,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.8072,
#              'longitude': 145.9738,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.3704,
#              'longitude': 145.8942,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37

#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 73,
#              'latitude': -37.444,
#              'longitude': 148.101,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 61,
#              'latitude': -37.562,
#              'longitude': 148.05,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.462,
#              'longitude': 148.089,
#              'surface_temperature_celcius': 90}}
# {'hotspot': {'confidence': 88,
#              'latitude': -37.46,
#              'longitude': 148.102,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 96,
#              'latitude': -38.127,
#              'longitude': 143.82,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.294,
#              'longitude': 141.232,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.293,
#              'longitude': 141.245,
#              'surface_temperature_celcius': 85}}
# {'hotspot': {'confidence': 91,
#              'latitude': -37.247,
#              'longitude': 141.278,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 92,
#              'latitude': -36.098,
#              'longitude': 143.74,
#              'surface_temperature_celcius': 67}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.331,
#              'longitude': 143.122,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.477,
#              'longitude': 143.352,
#              'surface_temperature_celcius': 93}}
# {'hotspot': {'confidence': 96,
#              'latitude': -37.475,
#              'longitude': 143.365,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.69,
#              'longitude': 143.605,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 89,
#              'latitude': -36.94,
#              'longitude': 143.281,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 87,
#              'latitude': -37.862,
#              'longitude': 144.175,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.945,
#              'longitude': 144.354,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.606,
#              'longitude': 149.312,
#              'surface_temperature_celcius': 87}}
# {'hotspot': {'confidence': 97,
#              'latitude': -37.61,
#              'longitude': 149.307,
#              'surface_temperature_celcius': 80}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.609,
#              'longitude': 149.32,
#              'surface_temperature_celcius': 84}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.642,
#              'longitude': 149.263,
#              'surface_temperature_celcius': 65}}
# {'hotspot': {'confidence': 100,
#              'latitude': -37.634,
#              'longitude': 149.237,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 98,
#              'latitude': -37.605,
#              'longitude': 149.302,
#              'surface_temperature_celcius': 83}}
# {'hotspot': {'confidence': 99,
#              'latitude': -37.6,
#              'longitude': 149.325,
#              'surface_temperature_celcius': 86}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.618,
#              'longitude': 149.281,
#              'surface_temperature_celcius': 76}}
# {'hotspot': {'confidence': 100,
#              'latitude': -36.282,
#              'longitude': 146.157,
#              'surface_temperature_celcius': 71}}
# {'hotspot': {'confidence': 92,
#              'latitude': -37.95,
#              'longitude': 142.366,
#              'surface_temperature_celcius': 70}}
# {'hotspot': {'confidence': 93,
#              'latitude': -37.875,
#              'longitude': 142.51,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 95,
#              'latitude': -37.613,
#              'longitude': 149.305,
#              'surface_temperature_celcius': 75}}
# {'hotspot': {'confidence': 90,
#              'latitude': -37.624,
#              'longitude': 149.314,
#              'surface_temperature_celcius': 66}}
# {'hotspot': {'confidence': 93,
#              'latitude': -38.057,
#              'longitude': 144.211,
#              'surface_temperature_celcius': 73}}
# {'hotspot': {'confidence': 78,
#              'latitude': -37.966,
#              'longitude': 145.051,
#              'surface_temperature_celcius': 68}}
# {'hotspot': {'confidence': 86,
#              'latitude': -35.543,
#              'longitude': 143.316,
#              'surface_temperature_celcius': 67}}

# %%
# c. Find date, surface temperature, air temperature, relative humidity and max wind speed
# on 15th and 16th of December 2021
cursor = collection.find(
    {
        "date" : {"$in":["15/12/21","16/12/21"]}
    },
    {
        "date":1, 
        "hotspot.surface_temperature_celcius": 1, 
        "air_temperature_celcius": 1,
        "relative_humidity":1,
        "max_wind_speed":1,
        "_id":0
    })
print_document(cursor)
# Out:
# {'air_temperature_celcius': 18,
#  'date': '15/12/21',
#  'hotspot': [{'surface_temperature_celcius': 42},
#              {'surface_temperature_celcius': 36},
#              {'surface_temperature_celcius': 38},
#              {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': '16/12/21',
#  'hotspot': [{'surface_temperature_celcius': 43},
#              {'surface_temperature_celcius': 33},
#              {'surface_temperature_celcius': 54},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 75},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 66},
#              {'surface_temperature_celcius': 56},
#              {'surface_temperature_celcius': 60},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 48},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 64},
#              {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
# d. Find datetime, air temperature, surface temperature and confidence 
# when the confidence is between 80 and 100
cursor = collection.find(
    {
        "hotspot.confidence": {"$gte":80, "$lte": 100}
    }, 
    {
        "hotspot.datetime": 1,
        "air_temperature_celcius":1,
        "hotspot.surface_temperature_celcius":1,
        "_id":0
    })
print_document(cursor)
# Out:
# {'air_temperature_celcius': 20,
#  'hotspot': [{'datetime': '2021-03-06T05:06:30',
#               'surface_temperature_celcius': 62},
#              {'datetime': '2021-03-06T05:06:20',
#               'surface_temperature_celcius': 59}]}
# {'air_temperature_celcius': 19,
#  'hotspot': [{'datetime': '2021-03-07T04:16:10',
#               'surface_temperature_celcius': 64}]}
# {'air_temperature_celcius': 23,
#  'hotspot': [{'datetime': '2021-03-09T13:23:40',
#               'surface_temperature_celcius': 41},
#              {'datetime': '2021-03-09T03:57:00',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-03-09T03:56:50',
#               'surface_temperature_celcius': 55}]}
# {'air_temperature_celcius': 19,
#  'hotspot': [{'datetime': '2021-03-10T04:48:40',
#               'surface_temperature_celcius': 105},
#              {'datetime': '2021-03-10T04:46:20',
#               'surface_temperature_celcius': 109},
#              {'datetime': '2021-03-10T04:45:30',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-03-10T04:45:30',
#               'surface_temperature_celcius': 80},
#              {'datetime': '2021-03-10T04:43:50',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-10T04:43:00',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-03-10T04:42:30',
#               'surface_temperature_celcius': 43},
#              {'datetime': '2021-03-10T04:39:00',
#               'surface_temperature_celcius': 48}]}
# {'air_temperature_celcius': 21,
#  'hotspot': [{'datetime': '2021-03-12T04:33:50',
#               'surface_temperature_celcius': 105},
#              {'datetime': '2021-03-12T04:29:50',
#               'surface_temperature_celcius': 71},
#              {'datetime': '2021-03-12T04:28:20',
#               'surface_temperature_celcius': 99},
#              {'datetime': '2021-03-12T04:28:00',
#               'surface_temperature_celcius': 68},
#              {'datetime': '2021-03-12T04:27:20',
#               'surface_temperature_celcius': 98}]}
# {'air_temperature_celcius': 25,
#  'hotspot': [{'datetime': '2021-03-14T04:24:40',
#               'surface_temperature_celcius': 67},
#              {'datetime': '2021-03-14T04:22:20',
#               'surface_temperature_celcius': 72},
#              {'datetime': '2021-03-14T04:20:50',
#               'surface_temperature_celcius': 68},
#              {'datetime': '2021-03-14T04:19:30',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-03-14T04:16:30',
#               'surface_temperature_celcius': 75},
#              {'datetime': '2021-03-14T04:16:20',
#               'surface_temperature_celcius': 65},
#              {'datetime': '2021-03-14T04:14:40',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-03-14T04:14:40',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-14T04:14:30',
#               'surface_temperature_celcius': 79},
#              {'datetime': '2021-03-14T04:14:30',
#               'surface_temperature_celcius': 75}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-03-17T04:48:20',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-03-17T04:48:20',
#               'surface_temperature_celcius': 74},
#              {'datetime': '2021-03-17T04:46:40',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-03-17T04:45:10',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-03-17T04:45:00',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-03-17T04:45:00',
#               'surface_temperature_celcius': 60}]}
# {'air_temperature_celcius': 21,
#  'hotspot': [{'datetime': '2021-03-18T13:16:50',
#               'surface_temperature_celcius': 37},
#              {'datetime': '2021-03-18T03:50:50',
#               'surface_temperature_celcius': 121},
#              {'datetime': '2021-03-18T03:50:40',
#               'surface_temperature_celcius': 80}]}
# {'air_temperature_celcius': 24,
#  'hotspot': [{'datetime': '2021-03-19T04:39:50',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-03-19T04:39:20',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-19T04:39:20',
#               'surface_temperature_celcius': 79},
#              {'datetime': '2021-03-19T04:39:20',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-19T04:36:00',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-03-19T04:36:00',
#               'surface_temperature_celcius': 66},
#              {'datetime': '2021-03-19T04:35:00',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-03-19T04:33:50',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-03-19T04:33:30',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-19T04:33:30',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-19T04:33:10',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-03-19T04:33:00',
#               'surface_temperature_celcius': 83},
#              {'datetime': '2021-03-19T04:32:50',
#               'surface_temperature_celcius': 91},
#              {'datetime': '2021-03-19T04:32:50',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-03-19T04:32:50',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-19T04:32:40',
#               'surface_temperature_celcius': 113},
#              {'datetime': '2021-03-19T04:32:40',
#               'surface_temperature_celcius': 70},
#              {'datetime': '2021-03-19T04:32:40',
#               'surface_temperature_celcius': 106},
#              {'datetime': '2021-03-19T04:32:40',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-03-19T00:15:50',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-03-19T00:12:50',
#               'surface_temperature_celcius': 44}]}
# {'air_temperature_celcius': 23,
#  'hotspot': [{'datetime': '2021-03-25T04:03:10',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-03-25T04:03:10',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-25T03:59:50',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-03-25T03:59:50',
#               'surface_temperature_celcius': 65},
#              {'datetime': '2021-03-25T03:58:10',
#               'surface_temperature_celcius': 62},
#              {'datetime': '2021-03-25T03:58:10',
#               'surface_temperature_celcius': 75},
#              {'datetime': '2021-03-25T03:57:10',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-03-25T03:57:10',
#               'surface_temperature_celcius': 111},
#              {'datetime': '2021-03-25T03:57:10',
#               'surface_temperature_celcius': 77},
#              {'datetime': '2021-03-25T03:56:50',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-03-25T03:56:40',
#               'surface_temperature_celcius': 99},
#              {'datetime': '2021-03-25T03:56:40',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-03-25T03:56:40',
#               'surface_temperature_celcius': 57}]}
# {'air_temperature_celcius': 23,
#  'hotspot': [{'datetime': '2021-03-26T04:47:20',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-03-26T04:43:40',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-03-26T04:43:20',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-26T04:41:10',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-03-26T04:40:50',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-03-26T04:40:10',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-03-26T04:39:50',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 68},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 70},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 89},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 62},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-03-26T04:39:10',
#               'surface_temperature_celcius': 48}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-03-28T04:38:00',
#               'surface_temperature_celcius': 64},
#              {'datetime': '2021-03-28T04:37:30',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-03-28T04:33:40',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-03-28T04:33:30',
#               'surface_temperature_celcius': 71},
#              {'datetime': '2021-03-28T04:33:30',
#               'surface_temperature_celcius': 76},
#              {'datetime': '2021-03-28T04:33:20',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-03-28T04:32:20',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-03-28T04:31:50',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-03-28T04:31:50',
#               'surface_temperature_celcius': 45},
#              {'datetime': '2021-03-28T04:30:50',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-03-28T04:30:20',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 74},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 82},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 80},
#              {'datetime': '2021-03-28T04:30:10',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-03-28T04:29:30',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-03-28T04:28:30',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-03-28T04:28:30',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-03-28T04:28:30',
#               'surface_temperature_celcius': 63},
#              {'datetime': '2021-03-28T04:28:30',
#               'surface_temperature_celcius': 62},
#              {'datetime': '2021-03-28T04:28:00',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021

#              {'datetime': '2021-04-06T04:20:40',
#               'surface_temperature_celcius': 72},
#              {'datetime': '2021-04-06T04:20:40',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-04-06T04:20:40',
# ...
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-10-04T04:41:00',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-10-04T04:41:00',
#               'surface_temperature_celcius': 58}]}
# {'air_temperature_celcius': 17,
#  'hotspot': [{'datetime': '2021-10-07T12:59:33',
#               'surface_temperature_celcius': 42}]}
# {'air_temperature_celcius': 13,
#  'hotspot': [{'datetime': '2021-10-10T04:04:34',
#               'surface_temperature_celcius': 40},
#              {'datetime': '2021-10-10T04:04:19',
#               'surface_temperature_celcius': 77},
#              {'datetime': '2021-10-10T04:04:19',
#               'surface_temperature_celcius': 43}]}
# {'air_temperature_celcius': 13,
#  'hotspot': [{'datetime': '2021-10-15T04:23:01',
#               'surface_temperature_celcius': 87},
#              {'datetime': '2021-10-15T04:23:01',
#               'surface_temperature_celcius': 85},
#              {'datetime': '2021-10-15T00:08:42',
#               'surface_temperature_celcius': 46}]}
# {'air_temperature_celcius': 22,
#  'hotspot': [{'datetime': '2021-10-17T13:36:12',
#               'surface_temperature_celcius': 43},
#              {'datetime': '2021-10-17T04:10:59',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-10-17T04:10:45',
#               'surface_temperature_celcius': 68},
#              {'datetime': '2021-10-17T04:10:38',
#               'surface_temperature_celcius': 41},
#              {'datetime': '2021-10-17T04:10:32',
#               'surface_temperature_celcius': 55}]}
# {'air_temperature_celcius': 26,
#  'hotspot': [{'datetime': '2021-10-18T00:39:27',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-10-18T00:39:27',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-10-18T00:39:03',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-10-18T00:39:02',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-10-18T00:39:02',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-10-18T00:39:02',
#               'surface_temperature_celcius': 49}]}
# {'air_temperature_celcius': 13,
#  'hotspot': [{'datetime': '2021-10-20T04:41:19',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-10-20T04:41:19',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-10-20T00:27:12',
#               'surface_temperature_celcius': 54}]}
# {'air_temperature_celcius': 12,
#  'hotspot': [{'datetime': '2021-10-21T01:09:55',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-10-21T01:09:55',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-10-21T01:09:54',
#               'surface_temperature_celcius': 35},
#              {'datetime': '2021-10-21T01:09:54',
#               'surface_temperature_celcius': 67}]}
# {'air_temperature_celcius': 13,
#  'hotspot': [{'datetime': '2021-10-26T13:30:31',
#               'surface_temperature_celcius': 36},
#              {'datetime': '2021-10-26T13:30:31',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-10-26T13:30:31',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-10-26T04:04:53',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-10-26T04:04:53',
#               'surface_temperature_celcius': 44}]}
# {'air_temperature_celcius': 22,
#  'hotspot': [{'datetime': '2021-10-27T04:47:31',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-10-27T04:47:31',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-10-27T04:47:31',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-10-27T00:33:09',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-10-27T00:33:09',
#               'surface_temperature_celcius': 47}]}
# {'air_temperature_celcius': 15,
#  'hotspot': [{'datetime': '2021-10-28T03:52:17',
#               'surface_temperature_celcius': 56}]}
# {'air_temperature_celcius': 13,
#  'hotspot': [{'datetime': '2021-11-05T04:41:34',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-11-05T04:41:34',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-11-05T04:41:19',
#               'surface_temperature_celcius': 65},
#              {'datetime': '2021-11-05T04:41:19',
#               'surface_temperature_celcius': 62}]}
# {'air_temperature_celcius': 14,
#  'hotspot': [{'datetime': '2021-11-09T04:16:56',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-11-09T04:16:56',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-11-09T04:16:53',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-11-09T04:16:48',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-11-09T04:16:48',
#               'surface_temperature_celcius': 47},
#              {'datetime': '2021-11-09T04:16:48',
#               'surface_temperature_celcius': 93},
#              {'datetime': '2021-11-09T04:16:48',
#               'surface_temperature_celcius': 77},
#              {'datetime': '2021-11-09T04:16:46',
#               'surface_temperature_celcius': 41},
#              {'datetime': '2021-11-09T04:16:44',
#               'surface_temperature_celcius': 62},
#              {'datetime': '2021-11-09T04:16:44',
#               'surface_temperature_celcius': 80}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-11-11T15:08:00',
#               'surface_temperature_celcius': 29},
#              {'datetime': '2021-11-11T13:30:08',
#               'surface_temperature_celcius': 37},
#              {'datetime': '2021-11-11T13:30:08',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-11-11T04:04:25',
#               'surface_temperature_celcius': 60}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-11-12T04:47:32',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-11-12T04:47:16',
#               'surface_temperature_celcius': 41},
#              {'datetime': '2021-11-12T04:46:53',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-11-12T00:33:15',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-11-12T00:33:15',
#               'surface_temperature_celcius': 69}]}
# {'air_temperature_celcius': 24,
#  'hotspot': [{'datetime': '2021-11-13T03:52:15',
#               'surface_temperature_celcius': 61},
#              {'datetime': '2021-11-13T03:52:14',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-11-13T03:52:08',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-11-13T01:16:38',
#               'surface_temperature_celcius': 38},
#              {'datetime': '2021-11-13T01:16:37',
#               'surface_temperature_celcius': 41}]}
# {'air_temperature_celcius': 28,
#  'hotspot': [{'datetime': '2021-11-14T04:35:04',
#               'surface_temperature_celcius': 65},
#              {'datetime': '2021-11-14T00:21:26',
#               'surface_temperature_celcius': 45},
#              {'datetime': '2021-11-14T00:21:07',
#               'surface_temperature_celcius': 46}]}
# {'air_temperature_celcius': 24,
#  'hotspot': [{'datetime': '2021-11-21T00:27:21',
#               'surface_temperature_celcius': 59}]}
# {'air_temperature_celcius': 23,
#  'hotspot': [{'datetime': '2021-11-22T03:46:00',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-11-22T03:46:00',
#               'surface_temperature_celcius': 64}]}
# {'air_temperature_celcius': 24,
#  'hotspot': [{'datetime': '2021-11-23T04:28:59',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-11-23T04:28:59',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-11-23T00:15:12',
#               'surface_temperature_celcius': 46},
#              {'datetime': '2021-11-23T00:14:47',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-11-23T00:14:24',
#               'surface_temperature_celcius': 55}]}
# {'air_temperature_celcius': 28,
#  'hotspot': [{'datetime': '2021-11-29T13:17:24',
#               'surface_temperature_celcius': 38},
#              {'datetime': '2021-11-29T13:17:24',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-11-29T13:17:24',
#               'surface_temperature_celcius': 43},
#              {'datetime': '2021-11-29T03:53:16',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-11-29T03:52:10',
#               'surface_temperature_celcius': 87},
#              {'datetime': '2021-11-29T03:52:10',
#               'surface_temperature_celcius': 44},
#              {'datetime': '2021-11-29T03:52:10',
#               'surface_temperature_celcius': 80},
#              {'datetime': '2021-11-29T03:52:10',
#               'surface_temperature_celcius': 84}]}
# {'air_temperature_celcius': 26,
#  'hotspot': [{'datetime': '2021-11-30T23:25:57',
#               'surface_temperature_celcius': 47},
#              {'datetime': '2021-11-30T15:38:36',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-11-30T15:38:36',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-11-30T15:38:36',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-11-30T15:38:35',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-11-30T15:38:35',
#               'surface_temperature_celcius': 35},
#              {'datetime': '2021-11-30T15:38:35',
#               'surface_temperature_celcius': 49},
#              {'datetime': '2021-11-30T15:38:32',
#               'surface_temperature_celcius': 31},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 33},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 32},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 38},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-11-30T12:22:15',
#               'surface_temperature_celcius': 65},
#              {'datetime': '2021-11-30T12:22:14',
#               'surface_temperature_celcius': 71},
#              {'datetime': '2021-11-30T04:35:00',
#               'surface_temperature_celcius': 59},
#              {'datetime': '2021-11-30T04:35:00',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-11-30T04:34:57',
#               'surface_temperature_celcius': 83},
#              {'datetime': '2021-11-30T04:34:57',
#               'surface_temperature_celcius': 57},
#              {'datetime': '2021-11-30T04:34:57',
#               'surface_temperature_celcius': 61},
#              {'datetime': '2021-11-30T04:34:57',
#               'surface_temperature_celcius': 86},
#              {'datetime': '2021-11-30T04:34:57',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-11-30T00:21:00',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 63},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 76},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 51},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-11-30T00:20:53',
#               'surface_temperature_celcius': 50},
#              {'datetime': '2021-11-30T00:20:49',
#               'surface_temperature_celcius': 41}]}
# {'air_temperature_celcius': 15,
#  'hotspot': [{'datetime': '2021-12-08T13:11:44',
#               'surface_temperature_celcius': 36},
#              {'datetime': '2021-12-08T13:11:44',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-12-08T13:11:44',
#               'surface_temperature_celcius': 71},
#              {'datetime': '2021-12-08T13:11:43',
#               'surface_temperature_celcius': 52},
#              {'datetime': '2021-12-08T13:11:43',
#               'surface_temperature_celcius': 40}]}
# {'air_temperature_celcius': 17,
#  'hotspot': [{'datetime': '2021-12-09T00:14:34',
#               'surface_temperature_celcius': 61},
#              {'datetime': '2021-12-09T00:14:34',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-12-09T00:14:33',
#               'surface_temperature_celcius': 58},
#              {'datetime': '2021-12-09T00:14:33',
#               'surface_temperature_celcius': 60}]}
# {'air_temperature_celcius': 28,
#  'hotspot': [{'datetime': '2021-12-13T04:04:19',
#               'surface_temperature_celcius': 60}]}
# {'air_temperature_celcius': 17,
#  'hotspot': [{'datetime': '2021-12-14T04:47:25',
#               'surface_temperature_celcius': 70}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-12-15T13:17:17',
#               'surface_temperature_celcius': 42},
#              {'datetime': '2021-12-15T13:17:17',
#               'surface_temperature_celcius': 36},
#              {'datetime': '2021-12-15T13:17:17',
#               'surface_temperature_celcius': 38},
#              {'datetime': '2021-12-15T01:16:23',
#               'surface_temperature_celcius': 40}]}
# {'air_temperature_celcius': 18,
#  'hotspot': [{'datetime': '2021-12-16T15:38:39',
#               'surface_temperature_celcius': 43},
#              {'datetime': '2021-12-16T15:38:39',
#               'surface_temperature_celcius': 33},
#              {'datetime': '2021-12-16T04:35:15',
#               'surface_temperature_celcius': 54},
#              {'datetime': '2021-12-16T04:35:13',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-12-16T04:34:58',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-12-16T04:34:58',
#               'surface_temperature_celcius': 75},
#              {'datetime': '2021-12-16T04:34:57',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-12-16T04:34:57',
#               'surface_temperature_celcius': 66},
#              {'datetime': '2021-12-16T04:34:57',
#               'surface_temperature_celcius': 56},
#              {'datetime': '2021-12-16T04:34:57',
#               'surface_temperature_celcius': 60},
#              {'datetime': '2021-12-16T00:21:12',
#               'surface_temperature_celcius': 73},
#              {'datetime': '2021-12-16T00:21:11',
#               'surface_temperature_celcius': 48},
#              {'datetime': '2021-12-16T00:21:11',
#               'surface_temperature_celcius': 55},
#              {'datetime': '2021-12-16T00:20:53',
#               'surface_temperature_celcius': 64},
#              {'datetime': '2021-12-16T00:20:53',
#               'surface_temperature_celcius': 57}]}
# {'air_temperature_celcius': 17,
#  'hotspot': [{'datetime': '2021-12-25T04:29:08',
#               'surface_temperature_celcius': 54}]}
# {'air_temperature_celcius': 28,
#  'hotspot': [{'datetime': '2021-12-27T04:16:51',
#               'surface_temperature_celcius': 68},
#              {'datetime': '2021-12-27T00:02:15',
#               'surface_temperature_celcius': 63},
#              {'datetime': '2021-12-27T00:02:15',
#               'surface_temperature_celcius': 53},
#              {'datetime': '2021-12-27T00:02:14',
#               'surface_temperature_celcius': 67}]}

# %%
# e. Find the top 10 records with the highest surface temperature
cursor = collection.aggregate([
    {
        "$unwind":"$hotspot"
    },
    {
        "$sort": {
            "hotspot.surface_temperature_celcius":-1
        }
    },
    {
        "$limit":10
    }
])
print_document(cursor)
# Out:
# {'GHI_w/m2': 122,
#  '_id': ObjectId('628dfe1c2c4f1386af17d743'),
#  'air_temperature_celcius': 15,
#  'cause_of_fire': 'other',
#  'date': '18/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-18T04:52:00',
#              'latitude': -38.1665,
#              'longitude': 143.062,
#              'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.1,
#  'station': '948701',
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('628dfe1c2c4f1386af17d735'),
#  'air_temperature_celcius': 16,
#  'cause_of_fire': 'other',
#  'date': '4/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-04T04:32:50',
#              'latitude': -36.343,
#              'longitude': 142.1986,
#              'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('628dfe1c2c4f1386af17d750'),
#  'air_temperature_celcius': 14,
#  'cause_of_fire': 'other',
#  'date': '1/5/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-05-01T04:14:20',
#              'latitude': -36.9318,
#              'longitude': 143.0907,
#              'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.12,
#  'relative_humidity': 49.2,
#  'station': '948701',
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('628dfe1c2c4f1386af17d724'),
#  'air_temperature_celcius': 21,
#  'cause_of_fire': 'other',
#  'date': '18/3/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-03-18T03:50:50',
#              'latitude': -37.017,
#              'longitude': 148.1297,
#              'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.8,
#  'station': '948701',
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('628dfe1c2c4f1386af17d735'),
#  'air_temperature_celcius': 16,
#  'cause_of_fire': 'other',
#  'date': '4/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-04T04:32:40',
#              'latitude': -36.3521,
#              'longitude': 142.2008,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('628dfe1c2c4f1386af17d73e'),
#  'air_temperature_celcius': 16,
#  'cause_of_fire': 'other',
#  'date': '13/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-13T04:28:10',
#              'latitude': -37.0745,
#              'longitude': 141.0692,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.9,
#  'station': '948701',
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('628dfe1c2c4f1386af17d75c'),
#  'air_temperature_celcius': 9,
#  'cause_of_fire': 'other',
#  'date': '13/5/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-05-13T04:40:20',
#              'latitude': -34.9938,
#              'longitude': 141.876,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 44.0,
#  'station': '948701',
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('628dfe1c2c4f1386af17d743'),
#  'air_temperature_celcius': 15,
#  'cause_of_fire': 'other',
#  'date': '18/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-18T04:44:50',
#              'latitude': -37.8326,
#              'longitude': 143.4999,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.1,
#  'station': '948701',
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('628dfe1c2c4f1386af17d735'),
#  'air_temperature_celcius': 16,
#  'cause_of_fire': 'other',
#  'date': '4/4/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-04-04T04:40:00',
#              'latitude': -36.1057,
#              'longitude': 141.7608,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('628dfe1c2c4f1386af17d753'),
#  'air_temperature_celcius': 10,
#  'cause_of_fire': 'other',
#  'date': '4/5/21',
#  'hotspot': {'confidence': 100,
#              'datetime': '2021-05-04T04:44:50',
#              'latitude': -36.4057,
#              'longitude': 140.9806,
#              'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 43.3,
#  'station': '948701',
#  'windspeed_knots': 2.6}

# %%
# f. Find the number of fires each day.
cursor = collection.aggregate([
    {
        "$project":{
            "_id":0,
            "date":1,
            "number_of_fire":{
                "$size":{
                    "$ifNull":["$hotspot",[]]
                }
            }
        }
    }
])
print_document(cursor)
# Out:
# {'date': '31/12/20', 'number_of_fire': 0}
# {'date': '2/1/21', 'number_of_fire': 0}
# {'date': '3/1/21', 'number_of_fire': 0}
# {'date': '4/1/21', 'number_of_fire': 0}
# {'date': '5/1/21', 'number_of_fire': 0}
# {'date': '6/1/21', 'number_of_fire': 0}
# {'date': '7/1/21', 'number_of_fire': 0}
# {'date': '8/1/21', 'number_of_fire': 0}
# {'date': '9/1/21', 'number_of_fire': 0}
# {'date': '10/1/21', 'number_of_fire': 0}
# {'date': '11/1/21', 'number_of_fire': 0}
# {'date': '12/1/21', 'number_of_fire': 0}
# {'date': '13/1/21', 'number_of_fire': 0}
# {'date': '14/1/21', 'number_of_fire': 0}
# {'date': '15/1/21', 'number_of_fire': 0}
# {'date': '16/1/21', 'number_of_fire': 0}
# {'date': '17/1/21', 'number_of_fire': 0}
# {'date': '18/1/21', 'number_of_fire': 0}
# {'date': '19/1/21', 'number_of_fire': 0}
# {'date': '20/1/21', 'number_of_fire': 0}
# {'date': '21/1/21', 'number_of_fire': 0}
# {'date': '22/1/21', 'number_of_fire': 0}
# {'date': '23/1/21', 'number_of_fire': 0}
# {'date': '24/1/21', 'number_of_fire': 0}
# {'date': '25/1/21', 'number_of_fire': 0}
# {'date': '26/1/21', 'number_of_fire': 0}
# {'date': '27/1/21', 'number_of_fire': 0}
# {'date': '28/1/21', 'number_of_fire': 0}
# {'date': '29/1/21', 'number_of_fire': 0}
# {'date': '30/1/21', 'number_of_fire': 0}
# {'date': '31/1/21', 'number_of_fire': 0}
# {'date': '1/2/21', 'number_of_fire': 0}
# {'date': '2/2/21', 'number_of_fire': 0}
# {'date': '3/2/21', 'number_of_fire': 0}
# {'date': '9/10/21', 'number_of_fire': 1}
# {'date': '10/10/21', 'number_of_fire': 3}
# {'date': '11/10/21', 'number_of_fire': 0}
# {'date': '12/10/21', 'number_of_fire': 0}
# {'date': '13/10/21', 'number_of_fire': 0}
# {'date': '14/10/21', 'number_of_fire': 0}
# {'date': '15/10/21', 'number_of_fire': 3}
# {'date': '16/10/21', 'number_of_fire': 1}
# {'date': '17/10/21', 'number_of_fire': 5}
# {'date': '18/10/21', 'number_of_fire': 6}
# {'date': '19/10/21', 'number_of_fire': 0}
# {'date': '20/10/21', 'number_of_fire': 3}
# {'date': '21/10/21', 'number_of_fire': 4}
# {'date': '22/10/21', 'number_of_fire': 0}
# {'date': '23/10/21', 'number_of_fire': 1}
# {'date': '24/10/21', 'number_of_fire': 0}
# {'date': '25/10/21', 'number_of_fire': 0}
# {'date': '26/10/21', 'number_of_fire': 5}
# {'date': '27/10/21', 'number_of_fire': 5}
# {'date': '28/10/21', 'number_of_fire': 1}
# {'date': '29/10/21', 'number_of_fire': 0}
# {'date': '30/10/21', 'number_of_fire': 0}
# {'date': '31/10/21', 'number_of_fire': 0}
# {'date': '1/11/21', 'number_of_fire': 0}
# {'date': '2/11/21', 'number_of_fire': 0}
# {'date': '3/11/21', 'number_of_fire': 0}
# {'date': '4/11/21', 'number_of_fire': 0}
# {'date': '5/11/21', 'number_of_fire': 4}
# {'date': '6/11/21', 'number_of_fire': 0}
# {'date': '7/11/21', 'number_of_fire': 0}
# {'date': '8/11/21', 'number_of_fire': 2}
# {'date': '9/11/21', 'number_of_fire': 10}
# {'date': '10/11/21', 'number_of_fire': 0}
# {'date': '11/11/21', 'number_of_fire': 4}
# {'date': '12/11/21', 'number_of_fire': 5}
# {'date': '13/11/21', 'number_of_fire': 5}
# {'date': '14/11/21', 'number_of_fire': 3}
# {'date': '15/11/21', 'number_of_fire': 0}
# {'date': '16/11/21', 'number_of_fire': 0}
# {'date': '17/11/21', 'number_of_fire': 0}
# {'date': '18/11/21', 'number_of_fire': 0}
# {'date': '19/11/21', 'number_of_fire': 0}
# {'date': '20/11/21', 'number_of_fire': 0}
# {'date': '21/11/21', 'number_of_fire': 1}
# {'date': '22/11/21', 'number_of_fire': 2}
# {'date': '23/11/21', 'number_of_fire': 5}
# {'date': '24/11/21', 'number_of_fire': 0}
# {'date': '25/11/21', 'number_of_fire': 0}
# {'date': '26/11/21', 'number_of_fire': 0}
# {'date': '27/11/21', 'number_of_fire': 0}
# {'date': '28/11/21', 'number_of_fire': 1}
# {'date': '29/11/21', 'number_of_fire': 8}
# {'date': '30/11/21', 'number_of_fire': 31}
# {'date': '1/12/21', 'number_of_fire': 0}
# {'date': '2/12/21', 'number_of_fire': 0}
# {'date': '3/12/21', 'number_of_fire': 0}
# {'date': '4/12/21', 'number_of_fire': 0}
# {'date': '5/12/21', 'number_of_fire': 0}
# {'date': '6/12/21', 'number_of_fire': 0}
# {'date': '7/12/21', 'number_of_fire': 0}
# {'date': '8/12/21', 'number_of_fire': 5}
# {'date': '9/12/21', 'number_of_fire': 4}
# {'date': '10/12/21', 'number_of_fire': 2}
# {'date': '11/12/21', 'number_of_fire': 0}
# {'date': '12/12/21', 'number_of_fire': 1}
# {'date': '13/12/21', 'number_of_fire': 1}
# {'date': '14/12/21', 'number_of_fire': 1}
# {'date': '15/12/21', 'number_of_fire': 4}
# {'date': '16/12/21', 'number_of_fire': 15}
# {'date': '17/12/21', 'number_of_fire': 0}
# {'date': '18/12/21', 'number_of_fire': 0}
# {'date': '19/12/21', 'number_of_fire': 0}
# {'date': '20/12/21', 'number_of_fire': 0}
# {'date': '21/12/21', 'number_of_fire': 1}
# {'date': '22/12/21', 'number_of_fire': 0}
# {'date': '23/12/21', 'number_of_fire': 0}
# {'date': '24/12/21', 'number_of_fire': 1}
# {'date': '25/12/21', 'number_of_fire': 1}
# {'date': '26/12/21', 'number_of_fire': 0}
# {'date': '27/12/21', 'number_of_fire': 4}
# {'date': '28/12/21', 'number_of_fire': 0}
# {'date': '29/12/21', 'number_of_fire': 0}
# {'date': '30/12/21', 'number_of_fire': 0}
# {'date': '31/12/21', 'number_of_fire': 0}
# {'date': '1/1/21', 'number_of_fire': 0}

# %%
# g. Find the records of fires where the confidence is below 70
cursor = collection.aggregate([
    {
        "$unwind": "$hotspot"
    },
    {
        "$match": {"hotspot.confidence":{"$lte":70}}
    },
    {
        "$project":{"hotspot":1,"_id":0}
    }
])
print_document(cursor)
# Out:
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-03-08T04:51:00',
#              'latitude': -37.7885,
#              'longitude': 141.9352,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 54,
#              'datetime': '2021-03-09T03:57:00',
#              'latitude': -37.7171,
#              'longitude': 147.5866,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 55,
#              'datetime': '2021-03-10T04:43:00',
#              'latitude': -36.2544,
#              'longitude': 148.0353,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 54,
#              'datetime': '2021-03-10T04:42:30',
#              'latitude': -37.2197,
#              'longitude': 147.9621,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 56,
#              'datetime': '2021-03-13T23:58:50',
#              'latitude': -37.0286,
#              'longitude': 148.155,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 52,
#              'datetime': '2021-03-13T12:57:00',
#              'latitude': -37.0316,
#              'longitude': 148.1519,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 52,
#              'datetime': '2021-03-15T00:42:50',
#              'latitude': -37.4075,
#              'longitude': 147.0233,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 66,
#              'datetime': '2021-03-15T00:42:50',
#              'latitude': -37.0228,
#              'longitude': 148.1281,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 51,
#              'datetime': '2021-03-15T00:42:40',
#              'latitude': -37.002,
#              'longitude': 148.2055,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-03-15T00:37:20',
#              'latitude': -37.4098,
#              'longitude': 147.0489,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-03-18T13:16:50',
#              'latitude': -37.4313,
#              'longitude': 147.0343,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 58,
#              'datetime': '2021-03-19T04:39:20',
#              'latitude': -37.9164,
#              'longitude': 143.4866,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 63,
#              'datetime': '2021-03-19T04:39:20',
#              'latitude': -37.9257,
#              'longitude': 143.4891,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-03-19T04:36:00',
#              'latitude': -37.3982,
#              'longitude': 147.0001,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 59,
#              'datetime': '2021-03-19T04:35:00',
#              'latitude': -37.4023,
#              'longitude': 147.0394,
#              'surface_temperature_celcius': 56}}
# {'hotspot': {'confidence': 60,
#              'datetime': '2021-03-19T04:33:50',
#              'latitude': -37.4336,
#              'longitude': 147.0534,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-03-19T04:33:30',
#              'latitude': -37.4003,
#              'longitude': 147.0448,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 53,
#              'datetime': '2021-03-19T04:33:30',
#              'latitude': -37.9184,
#              'longitude': 143.4745,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-03-19T04:33:10',
#              'latitude': -37.3911,
#              'longitude': 147.037,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 66,
#              'datetime': '2021

#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-04-13T04:26:40',
#              'latitude': -37.7635,
#              'longitude': 142.8181,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 53,
#              'datetime': '2021-04-13T04:26:40',
#              'latitude': -37.7982,
#              'longitude': 142.2386,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 66,
#              'datetime': '2021-04-13T04:26:40',
#              'latitude': -37.4391,
#              'longitude': 143.0293,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-04-13T04:26:40',
#              'latitude': -37.6161,
#              'longitude': 141.2781,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.6777,
#              'longitude': 141.37,
#              'surface_temperature_celcius': 49}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.6701,
#              'longitude': 141.3566,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.1574,
#              'longitude': 144.3672,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 67,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.4373,
#              'longitude': 143.6328,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.4392,
#              'longitude': 144.2111,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.3275,
#              'longitude': 145.5876,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.5418,
#              'longitude': 144.666,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.9875,
#              'longitude': 141.9298,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -36.7754,
#              'longitude': 143.5261,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-04-13T04:26:30',
#              'latitude': -37.2054,
#              'longitude': 141.1083,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-04-13T04:26:30',
# ...
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 58,
#              'datetime': '2021-09-23T23:50:40',
#              'latitude': -37.379,
#              'longitude': 148.126,
#              'surface_temperature_celcius': 82}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-09-23T23:50:40',
#              'latitude': -37.379,
#              'longitude': 148.132,
#              'surface_temperature_celcius': 78}}
# {'hotspot': {'confidence': 50,
#              'datetime': '2021-09-23T04:59:18',
#              'latitude': -36.984,
#              'longitude': 148.25,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-09-23T04:59:13',
#              'latitude': -37.347,
#              'longitude': 148.019,
#              'surface_temperature_celcius': 36}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-09-23T03:21:28',
#              'latitude': -36.996,
#              'longitude': 148.228,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 56,
#              'datetime': '2021-09-23T03:21:28',
#              'latitude': -36.995,
#              'longitude': 148.268,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 63,
#              'datetime': '2021-09-23T03:21:19',
#              'latitude': -37.554,
#              'longitude': 148.073,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-09-24T15:07:47',
#              'latitude': -37.434,
#              'longitude': 148.091,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 59,
#              'datetime': '2021-09-24T13:30:09',
#              'latitude': -37.375,
#              'longitude': 148.063,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 58,
#              'datetime': '2021-09-24T04:04:19',
#              'latitude': -37.397,
#              'longitude': 148.121,
#              'surface_temperature_celcius': 58}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-09-24T04:04:18',
#              'latitude': -37.452,
#              'longitude': 148.115,
#              'surface_temperature_celcius': 77}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-09-24T04:04:18',
#              'latitude': -37.465,
#              'longitude': 148.153,
#              'surface_temperature_celcius': 63}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-09-24T04:04:18',
#              'latitude': -37.45,
#              'longitude': 148.126,
#              'surface_temperature_celcius': 69}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-09-24T04:04:17',
#              'latitude': -37.562,
#              'longitude': 148.05,
#              'surface_temperature_celcius': 72}}
# {'hotspot': {'confidence': 56,
#              'datetime': '2021-09-24T04:04:04',
#              'latitude': -38.495,
#              'longitude': 146.944,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-09-26T03:52:14',
#              'latitude': -37.087,
#              'longitude': 145.37,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 65,
#              'datetime': '2021-09-27T04:35:18',
#              'latitude': -36.398,
#              'longitude': 145.286,
#              'surface_temperature_celcius': 39}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-09-29T04:22:41',
#              'latitude': -37.45,
#              'longitude': 148.097,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-10-01T15:13:56',
#              'latitude': -37.463,
#              'longitude': 148.109,
#              'surface_temperature_celcius': 34}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-10-01T04:10:28',
#              'latitude': -37.46,
#              'longitude': 148.113,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 50,
#              'datetime': '2021-10-02T23:44:31',
#              'latitude': -37.466,
#              'longitude': 148.1,
#              'surface_temperature_celcius': 29}}
# {'hotspot': {'confidence': 59,
#              'datetime': '2021-10-02T04:53:10',
#              'latitude': -37.475,
#              'longitude': 148.134,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-10-02T00:39:34',
#              'latitude': -37.456,
#              'longitude': 148.11,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-10-03T15:01:44',
#              'latitude': -37.461,
#              'longitude': 148.109,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-10-03T03:58:28',
#              'latitude': -37.236,
#              'longitude': 141.176,
#              'surface_temperature_celcius': 37}}
# {'hotspot': {'confidence': 59,
#              'datetime': '2021-10-03T03:58:28',
#              'latitude': -37.227,
#              'longitude': 141.151,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 54,
#              'datetime': '2021-10-03T01:22:44',
#              'latitude': -37.227,
#              'longitude': 141.146,
#              'surface_temperature_celcius': 31}}
# {'hotspot': {'confidence': 50,
#              'datetime': '2021-10-04T04:41:36',
#              'latitude': -36.418,
#              'longitude': 141.596,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-10-16T23:56:43',
#              'latitude': -37.288,
#              'longitude': 144.39,
#              'surface_temperature_celcius': 36}}
# {'hotspot': {'confidence': 58,
#              'datetime': '2021-10-17T04:10:38',
#              'latitude': -37.587,
#              'longitude': 142.479,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 65,
#              'datetime': '2021-10-20T00:27:12',
#              'latitude': -37.296,
#              'longitude': 144.386,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 65,
#              'datetime': '2021-10-21T01:09:54',
#              'latitude': -36.1,
#              'longitude': 143.772,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 67,
#              'datetime': '2021-10-26T04:04:53',
#              'latitude': -36.156,
#              'longitude': 143.568,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-10-26T04:04:53',
#              'latitude': -36.152,
#              'longitude': 143.578,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-10-27T04:47:31',
#              'latitude': -36.748,
#              'longitude': 144.168,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 60,
#              'datetime': '2021-11-08T05:12:08',
#              'latitude': -36.538,
#              'longitude': 141.129,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-11-09T04:16:56',
#              'latitude': -36.759,
#              'longitude': 145.179,
#              'surface_temperature_celcius': 52}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-11-09T04:16:56',
#              'latitude': -36.758,
#              'longitude': 145.19,
#              'surface_temperature_celcius': 51}}
# {'hotspot': {'confidence': 63,
#              'datetime': '2021-11-09T04:16:46',
#              'latitude': -37.719,
#              'longitude': 142.154,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 51,
#              'datetime': '2021-11-11T15:08:00',
#              'latitude': -36.943,
#              'longitude': 143.286,
#              'surface_temperature_celcius': 29}}
# {'hotspot': {'confidence': 63,
#              'datetime': '2021-11-12T04:47:32',
#              'latitude': -36.942,
#              'longitude': 143.282,
#              'surface_temperature_celcius': 53}}
# {'hotspot': {'confidence': 58,
#              'datetime': '2021-11-12T04:47:16',
#              'latitude': -37.864,
#              'longitude': 144.174,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 56,
#              'datetime': '2021-11-12T04:46:53',
#              'latitude': -38.912,
#              'longitude': 146.272,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 67,
#              'datetime': '2021-11-12T00:33:15',
#              'latitude': -36.942,
#              'longitude': 143.292,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-13T03:52:08',
#              'latitude': -37.954,
#              'longitude': 143.918,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 51,
#              'datetime': '2021-11-13T01:16:38',
#              'latitude': -38.167,
#              'longitude': 143.841,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-11-13T01:16:37',
#              'latitude': -38.16,
#              'longitude': 143.803,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-14T00:21:26',
#              'latitude': -38.527,
#              'longitude': 143.493,
#              'surface_temperature_celcius': 45}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-14T00:21:07',
#              'latitude': -37.332,
#              'longitude': 143.375,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-11-23T00:15:12',
#              'latitude': -38.141,
#              'longitude': 143.183,
#              'surface_temperature_celcius': 46}}
# {'hotspot': {'confidence': 63,
#              'datetime': '2021-11-23T00:14:47',
#              'latitude': -36.952,
#              'longitude': 144.972,
#              'surface_temperature_celcius': 60}}
# {'hotspot': {'confidence': 70,
#              'datetime': '2021-11-23T00:14:24',
#              'latitude': -34.965,
#              'longitude': 142.031,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 50,
#              'datetime': '2021-11-28T00:33:14',
#              'latitude': -37.749,
#              'longitude': 148.297,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 53,
#              'datetime': '2021-11-29T13:17:24',
#              'latitude': -37.611,
#              'longitude': 149.277,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 68,
#              'datetime': '2021-11-29T13:17:24',
#              'latitude': -37.605,
#              'longitude': 149.308,
#              'surface_temperature_celcius': 43}}
# {'hotspot': {'confidence': 52,
#              'datetime': '2021-11-29T03:53:16',
#              'latitude': -34.282,
#              'longitude': 142.121,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-29T03:52:10',
#              'latitude': -37.605,
#              'longitude': 149.326,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 52,
#              'datetime': '2021-11-30T23:25:57',
#              'latitude': -37.635,
#              'longitude': 149.303,
#              'surface_temperature_celcius': 47}}
# {'hotspot': {'confidence': 51,
#              'datetime': '2021-11-30T15:38:36',
#              'latitude': -37.59,
#              'longitude': 149.31,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-30T15:38:36',
#              'latitude': -37.633,
#              'longitude': 149.264,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-11-30T15:38:35',
#              'latitude': -37.58,
#              'longitude': 149.331,
#              'surface_temperature_celcius': 35}}
# {'hotspot': {'confidence': 61,
#              'datetime': '2021-11-30T15:38:32',
#              'latitude': -37.38,
#              'longitude': 149.334,
#              'surface_temperature_celcius': 31}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-11-30T12:22:15',
#              'latitude': -37.602,
#              'longitude': 149.295,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-30T12:22:15',
#              'latitude': -37.598,
#              'longitude': 149.29,
#              'surface_temperature_celcius': 32}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-11-30T04:34:57',
#              'latitude': -37.61,
#              'longitude': 149.279,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 60,
#              'datetime': '2021-11-30T00:21:00',
#              'latitude': -37.637,
#              'longitude': 146.288,
#              'surface_temperature_celcius': 42}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-11-30T00:20:53',
#              'latitude': -37.6,
#              'longitude': 149.297,
#              'surface_temperature_celcius': 50}}
# {'hotspot': {'confidence': 64,
#              'datetime': '2021-11-30T00:20:49',
#              'latitude': -37.382,
#              'longitude': 149.341,
#              'surface_temperature_celcius': 41}}
# {'hotspot': {'confidence': 56,
#              'datetime': '2021-12-08T13:11:43',
#              'latitude': -36.291,
#              'longitude': 146.159,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 50,
#              'datetime': '2021-12-10T00:57:59',
#              'latitude': -37.987,
#              'longitude': 144.005,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 67,
#              'datetime': '2021-12-10T00:56:57',
#              'latitude': -34.289,
#              'longitude': 141.712,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 53,
#              'datetime': '2021-12-12T00:45:38',
#              'latitude': -37.903,
#              'longitude': 145.25,
#              'surface_temperature_celcius': 44}}
# {'hotspot': {'confidence': 51,
#              'datetime': '2021-12-15T13:17:17',
#              'latitude': -37.623,
#              'longitude': 149.323,
#              'surface_temperature_celcius': 38}}
# {'hotspot': {'confidence': 65,
#              'datetime': '2021-12-15T01:16:23',
#              'latitude': -38.038,
#              'longitude': 142.986,
#              'surface_temperature_celcius': 40}}
# {'hotspot': {'confidence': 69,
#              'datetime': '2021-12-16T15:38:39',
#              'latitude': -37.624,
#              'longitude': 149.332,
#              'surface_temperature_celcius': 33}}
# {'hotspot': {'confidence': 62,
#              'datetime': '2021-12-16T04:35:15',
#              'latitude': -37.82,
#              'longitude': 142.323,
#              'surface_temperature_celcius': 54}}
# {'hotspot': {'confidence': 59,
#              'datetime': '2021-12-16T04:34:57',
#              'latitude': -37.644,
#              'longitude': 149.346,
#              'surface_temperature_celcius': 55}}
# {'hotspot': {'confidence': 60,
#              'datetime': '2021-12-16T00:21:11',
#              'latitude': -38.046,
#              'longitude': 144.201,
#              'surface_temperature_celcius': 48}}
# {'hotspot': {'confidence': 53,
#              'datetime': '2021-12-16T00:20:53',
#              'latitude': -37.63,
#              'longitude': 149.335,
#              'surface_temperature_celcius': 57}}
# {'hotspot': {'confidence': 65,
#              'datetime': '2021-12-24T13:12:01',
#              'latitude': -35.646,
#              'longitude': 142.282,
#              'surface_temperature_celcius': 32}}
# {'hotspot': {'confidence': 67,
#              'datetime': '2021-12-27T00:02:15',
#              'latitude': -35.554,
#              'longitude': 143.307,
#              'surface_temperature_celcius': 53}}

# %%
# h. Find the average surface temperature for each day
cursor = collection.aggregate([
    {
        "$project": {
            "_id":0,
            "date":1,
            "avg_surface_temperature":{
                "$avg": "$hotspot.surface_temperature_celcius"
            }
        }
    }
])
print_document(cursor)
# Out:
# {'avg_surface_temperature': None, 'date': '31/12/20'}
# {'avg_surface_temperature': None, 'date': '2/1/21'}
# {'avg_surface_temperature': None, 'date': '3/1/21'}
# {'avg_surface_temperature': None, 'date': '4/1/21'}
# {'avg_surface_temperature': None, 'date': '5/1/21'}
# {'avg_surface_temperature': None, 'date': '6/1/21'}
# {'avg_surface_temperature': None, 'date': '7/1/21'}
# {'avg_surface_temperature': None, 'date': '8/1/21'}
# {'avg_surface_temperature': None, 'date': '9/1/21'}
# {'avg_surface_temperature': None, 'date': '10/1/21'}
# {'avg_surface_temperature': None, 'date': '11/1/21'}
# {'avg_surface_temperature': None, 'date': '12/1/21'}
# {'avg_surface_temperature': None, 'date': '13/1/21'}
# {'avg_surface_temperature': None, 'date': '14/1/21'}
# {'avg_surface_temperature': None, 'date': '15/1/21'}
# {'avg_surface_temperature': None, 'date': '16/1/21'}
# {'avg_surface_temperature': None, 'date': '17/1/21'}
# {'avg_surface_temperature': None, 'date': '18/1/21'}
# {'avg_surface_temperature': None, 'date': '19/1/21'}
# {'avg_surface_temperature': None, 'date': '20/1/21'}
# {'avg_surface_temperature': None, 'date': '21/1/21'}
# {'avg_surface_temperature': None, 'date': '22/1/21'}
# {'avg_surface_temperature': None, 'date': '23/1/21'}
# {'avg_surface_temperature': None, 'date': '24/1/21'}
# {'avg_surface_temperature': None, 'date': '25/1/21'}
# {'avg_surface_temperature': None, 'date': '26/1/21'}
# {'avg_surface_temperature': None, 'date': '27/1/21'}
# {'avg_surface_temperature': None, 'date': '28/1/21'}
# {'avg_surface_temperature': None, 'date': '29/1/21'}
# {'avg_surface_temperature': None, 'date': '30/1/21'}
# {'avg_surface_temperature': None, 'date': '31/1/21'}
# {'avg_surface_temperature': None, 'date': '1/2/21'}
# {'avg_surface_temperature': None, 'date': '2/2/21'}
# {'avg_surface_temperature': None, 'date': '3/2/21'}
# {'avg_surface_temperature': None, 'date': '4/2/21'}
# {'avg_surface_temperature': None, 'date': '5/2/21'}
# {'avg_surface_temperature': None, 'date': '6/2/21'}
# {'avg_surface_temperature': None, 'date': '7/2/21'}
# {'avg_surface_temperature': None, 'date': '8/2/21'}
# {'avg_surface_temperature': None, 'date': '9/2/21'}
# {'avg_surface_temperature': None, 'date': '10/2/21'}
# {'avg_surface_temperature': None, 'date': '11/2/21'}
# {'avg_surface_temperature': None, 'date': '12/2/21'}
# {'avg_surface_temperature': None, 'date': '13/2/21'}
# {'avg_surface_temperature': None, 'date': '14/2/21'}
# {'avg_surface_temperature': None, 'date': '15/2/21'}
# {'avg_surface_temperature': None, 'date': '16/2/21'}
# {'avg_surface_temperature': None, 'date': '17/2/21'}
# {'avg_surface_temperature': None, 'date': '18/2/21'}
# {'avg_surface_temperature': None, 'date': '19/2/21'}
# {'avg_surface_temperature': None, 'date': '20/2/21'}
# {'avg_surface_temperature': None, 'date': '21/2/21'}
# {'avg_surface_temperature': None, 'date': '22/2/21'}
# {'avg_surface_temperature': None, 'date': '23/2/21'}
# {'avg_surface_temperature': None, 'date': '24/2/21'}
# {'avg_surface_temperature': None, 'date': '25/2/21'}
# {'avg_surface_temperature': None, 'date': '26/2/21'}
# {'avg_surface_temperature': None, 'date': '27/2/21'}
# {'avg_surface_temperature': None, 'date': '28/2/21'}
# {'avg_surface_temperature': None, 'date': '1/3/21'}
# {'avg_surface_temperature': None, 'date': '2/3/21'}
# {'avg_surface_temperature': None, 'date': '3/3/21'}
# {'avg_surface_temperature': None, 'date': '4/3/21'}
# {'avg_surface_temperature': None, 'date': '5/3/21'}
# {'avg_surface_temperature': 60.5, 'date': '6/3/21'}
# {'avg_surface_temperature': 64.0, 'date': '7/3/21'}
# {'avg_surface_temperature': 51.5, 'date': '8/3/21'}
# {'avg_surface_temperature': 46.666666666666664, 'date': '9/3/21'}
# {'avg_surface_temperature': 69.375, 'date': '10/3/21'}
# {'avg_surface_temperature': None, 'date': '11/3/21'}
# {'avg_surface_temperature': 88.2, 'date': '12/3/21'}
# {'avg_surface_temperature': 38.5, 'date': '13/3/21'}
# {'avg_surface_temperature': 65.6, 'date': '14/3/21'}
# {'avg_surface_temperature': 46.0, 'date': '15/3/21'}
# {'avg_surface_temperature': None, 'date': '16/3/21'}
# {'avg_surface_temperature': 59.5, 'date': '17/3/21'}
# {'avg_surface_temperature': 79.33333333333333, 'date': '18/3/21'}
# {'avg_surface_temperature': 65.57142857142857, 'date': '19/3/21'}
# {'avg_surface_temperature': None, 'date': '20/3/21'}
# {'avg_surface_temperature': None, 'date': '21/3/21'}
# {'avg_surface_temperature': None, 'date': '22/3/21'}
# {'avg_surface_temperature': None, 'date': '23/3/21'}
# {'avg_surface_temperature': 49.0, 'date': '24/3/21'}
# {'avg_surface_temperature': 66.0, 'date': '25/3/21'}
# {'avg_surface_temperature': 56.88235294117647, 'date': '26/3/21'}
# {'avg_surface_temperature': None, 'date': '27/3/21'}
# {'avg_surface_temperature': 60.925925925925924, 'date': '28/3/21'}
# {'avg_surface_temperature': 51.0, 'date': '29/3/21'}
# {'avg_surface_temperature': None, 'date': '30/3/21'}
# {'avg_surface_temperature': 48.72727272727273, 'date': '31/3/21'}
# {'avg_surface_temperature': 46.714285714285715, 'date': '1/4/21'}
# {'avg_surface_temperature': 45.2, 'date': '2/4/21'}
# {'avg_surface_temperature': 58.44444444444444, 'date': '3/4/21'}
# {'avg_surface_temperature': 62.57303370786517, 'date': '4/4/21'}
# {'avg_surface_temperature': 53.142857142857146, 'date': '5/4/21'}
# {'avg_surface_temperature': 61.71186440677966, 'date': '6/4/21'}
# {'avg_surface_temperature': 50.69230769230769, 'date': '7/4/21'}
# {'avg_surface_temperature': 60.75, 'date': '8/4/21'}
# {'avg_surface_temperature': None, 'date': '9/4/21'}
# {'avg_surface_temperature': None, 'date': '10/4/21'}
# {'avg_surface_temperature': 46.291666666666664, 'date': '11/4/21'}
# {'avg_surface_temperature': 52.69565217391305, 'date': '12/4/21'}
# {'avg_surface_temperature': 58.57983193277311, 'date': '13/4/21'}
# {'avg_surface_temperature': 61.94444444444444, 'date': '14/4/21'}
# {'avg_surface_temperature': 59.57971014492754, 'date': '15/4/21'}
# {'avg_surface_temperature': 48.72222222222222, 'date': '16/4/21'}
# {'avg_surface_temperature': 50.921052631578945, 'date': '17/4/21'}
# {'avg_surface_temperature': 53.36615384615384, 'date': '18/4/21'}
# {'avg_surface_temperature': 54.16, 'date': '19/4/21'}
# {'avg_surface_temperature': 56.58064516129032, 'date': '20/4/21'}
# {'avg_surface_temperature': None, 'date': '21/4/21'}
# {'avg_surface_temperature': 54.5, 'date': '22/4/21'}
# {'avg_surface_temperature': 53.89473684210526, 'date': '23/4/21'}
# {'avg_surface_temperature': 59.375, 'date': '24/4/21'}
# {'avg_surface_temperature': 48.666666666666664, 'date': '25/4/21'}
# {'avg_surface_temperature': 34.0, 'date': '26/4/21'}
# {'avg_surface_temperature': None, 'date': '27/4/21'}
# {'avg_surface_temperature': None, 'date': '28/4/21'}
# {'avg_surface_temperature': 63.0, 'date': '29/4/21'}
# {'avg_surface_temperature': None, 'date': '30/4/21'}
# {'avg_surface_temperature': 68.4, 'date': '1/5/21'}
# {'avg_surface_temperature': 55.6, 'date': '2/5/21'}
# {'avg_surface_temperature': 56.796875, 'date': '3/5/21'}
# {'avg_surface_temperature': 56.80740740740741, 'date': '4/5/21'}
# {'avg_surface_temperature': 51.70967741935484, 'date': '5/5/21'}
# {'avg_surface_temperature': 57.529411764705884, 'date': '6/5/21'}
# {'avg_surface_temperature': 50.333333333333336, 'date': '7/5/21'}
# {'avg_surface_temperature': 56.291666666666664, 'date': '8/5/21'}
# {'avg_surface_temperature': 42.46153846153846, 'date': '9/5/21'}
# {'avg_surface_temperature': 52.86842105263158, 'date': '10/5/21'}
# {'avg_surface_temperature': 59.36842105263158, 'date': '11/5/21'}
# {'avg_surface_temperature': 51.5, 'date': '12/5/21'}
# {'avg_surface_temperature': 58.611111111111114, 'date': '13/5/21'}
# {'avg_surface_temperature': 49.0, 'date': '14/5/21'}
# {'avg_surface_temperature': 53.950980392156865, 'date': '15/5/21'}
# {'avg_surface_temperature': 39.666666666666664, 'date': '16/5/21'}
# {'avg_surface_temperature': 52.0, 'date': '17/5/21'}
# {'avg_surface_temperature': 44.142857142857146, 'date': '18/5/21'}
# {'avg_surface_temperature': None, 'date': '19/5/21'}
# {'avg_surface_temperature': None, 'date': '20/5/21'}
# {'avg_surface_temperature': None, 'date': '21/5/21'}
# {'avg_surface_temperature': 54.484848484848484, 'date': '22/5/21'}
# {'avg_surface_temperature': 51.2, 'date': '23/5/21'}
# {'avg_surface_temperature': 40.333333333333336, 'date': '24/5/21'}
# {'avg_surface_temperature': None, 'date': '25/5/21'}
# {'avg_surface_temperature': 49.5, 'date': '26/5/21'}
# {'avg_surface_temperature': None, 'date': '27/5/21'}
# {'avg_surface_temperature': None, 'date': '28/5/21'}
# {'avg_surface_temperature': None, 'date': '29/5/21'}
# {'avg_surface_temperature': None, 'date': '30/5/21'}
# {'avg_surface_temperature': None, 'date': '31/5/21'}
# {'avg_surface_temperature': 54.0, 'date': '1/6/21'}
# {'avg_surface_temperature': 47.72727272727273, 'date': '2/6/21'}
# {'avg_surface_temperature': 47.0, 'date': '3/6/21'}
# {'avg_surface_temperature': 52.22222222222222, 'date': '4/6/21'}
# {'avg_surface_temperature': None, 'date': '5/6/21'}
# {'avg_surface_temperature': None, 'date': '6/6/21'}
# {'avg_surface_temperature': 51.857142857142854, 'date': '7/6/21'}
# {'avg_surface_temperature': None, 'date': '8/6/21'}
# {'avg_surface_temperature': 49.0, 'date': '9/6/21'}
# {'avg_surface_temperature': None, 'date': '10/6/21'}
# {'avg_surface_temperature': 41.5, 'date': '11/6/21'}
# {'avg_surface_temperature': None, 'date': '12/6/21'}
# {'avg_surface_temperature': 41.0, 'date': '13/6/21'}
# {'avg_surface_temperature': 53.25, 'date': '14/6/21'}
# {'avg_surface_temperature': None, 'date': '15/6/21'}
# {'avg_surface_temperature': 42.5, 'date': '16/6/21'}
# {'avg_surface_temperature': None, 'date': '17/6/21'}
# {'avg_surface_temperature': 42.0, 'date': '18/6/21'}
# {'avg_surface_temperature': None, 'date': '19/6/21'}
# {'avg_surface_temperature': 71.16666666666667, 'date': '20/6/21'}
# {'avg_surface_temperature': None, 'date': '21/6/21'}
# {'avg_surface_temperature': 46.0, 'date': '22/6/21'}
# {'avg_surface_temperature': None, 'date': '23/6/21'}
# {'avg_surface_temperature': None, 'date': '24/6/21'}
# {'avg_surface_temperature': None, 'date': '25/6/21'}
# {'avg_surface_temperature': None, 'date': '26/6/21'}
# {'avg_surface_temperature': None, 'date': '27/6/21'}
# {'avg_surface_temperature': None, 'date': '28/6/21'}
# {'avg_surface_temperature': None, 'date': '29/6/21'}
# {'avg_surface_temperature': 44.333333333333336, 'date': '30/6/21'}
# {'avg_surface_temperature': 30.5, 'date': '1/7/21'}
# {'avg_surface_temperature': 43.5, 'date': '2/7/21'}
# {'avg_surface_temperature': None, 'date': '3/7/21'}
# {'avg_surface_temperature': 40.0, 'date': '4/7/21'}
# {'avg_surface_temperature': 45.0, 'date': '5/7/21'}
# {'avg_surface_temperature': 56.0, 'date': '6/7/21'}
# {'avg_surface_temperature': None, 'date': '7/7/21'}
# {'avg_surface_temperature': None, 'date': '8/7/21'}
# {'avg_surface_temperature': None, 'date': '9/7/21'}
# {'avg_surface_temperature': None, 'date': '10/7/21'}
# {'avg_surface_temperature': None, 'date': '11/7/21'}
# {'avg_surface_temperature': None, 'date': '12/7/21'}
# {'avg_surface_temperature': None, 'date': '13/7/21'}
# {'avg_surface_temperature': 41.5, 'date': '14/7/21'}
# {'avg_surface_temperature': None, 'date': '15/7/21'}
# {'avg_surface_temperature': None, 'date': '16/7/21'}
# {'avg_surface_temperature': None, 'date': '17/7/21'}
# {'avg_surface_temperature': None, 'date': '18/7/21'}
# {'avg_surface_temperature': None, 'date': '19/7/21'}
# {'avg_surface_temperature': None, 'date': '20/7/21'}
# {'avg_surface_temperature': None, 'date': '21/7/21'}
# {'avg_surface_temperature': None, 'date': '22/7/21'}
# {'avg_surface_temperature': None, 'date': '23/7/21'}
# {'avg_surface_temperature': None, 'date': '24/7/21'}
# {'avg_surface_temperature': None, 'date': '25/7/21'}
# {'avg_surface_temperature': None, 'date': '26/7/21'}
# {'avg_surface_temperature': None, 'date': '27/7/21'}
# {'avg_surface_temperature': None, 'date': '28/7/21'}
# {'avg_surface_temperature': 48.0, 'date': '29/7/21'}
# {'avg_surface_temperature': None, 'date': '30/7/21'}
# {'avg_surface_temperature': 47.0, 'date': '31/7/21'}
# {'avg_surface_temperature': 58.0, 'date': '1/8/21'}
# {'avg_surface_temperature': 63.5, 'date': '2/8/21'}
# {'avg_surface_temperature': None, 'date': '3/8/21'}
# {'avg_surface_temperature': None, 'date': '4/8/21'}
# {'avg_surface_temperature': 40.0, 'date': '5/8/21'}
# {'avg_surface_temperature': None, 'date': '6/8/21'}
# {'avg_surface_temperature': None, 'date': '7/8/21'}
# {'avg_surface_temperature': None, 'date': '8/8/21'}
# {'avg_surface_temperature': None, 'date': '9/8/21'}
# {'avg_surface_temperature': 63.0, 'date': '10/8/21'}
# {'avg_surface_temperature': None, 'date': '11/8/21'}
# {'avg_surface_temperature': None, 'date': '12/8/21'}
# {'avg_surface_temperature': 49.0, 'date': '13/8/21'}
# {'avg_surface_temperature': 40.8, 'date': '14/8/21'}
# {'avg_surface_temperature': None, 'date': '15/8/21'}
# {'avg_surface_temperature': None, 'date': '16/8/21'}
# {'avg_surface_temperature': None, 'date': '17/8/21'}
# {'avg_surface_temperature': None, 'date': '18/8/21'}
# {'avg_surface_temperature': None, 'date': '19/8/21'}
# {'avg_surface_temperature': None, 'date': '20/8/21'}
# {'avg_surface_temperature': None, 'date': '21/8/21'}
# {'avg_surface_temperature': None, 'date': '22/8/21'}
# {'avg_surface_temperature': None, 'date': '23/8/21'}
# {'avg_surface_temperature': None, 'date': '24/8/21'}
# {'avg_surface_temperature': None, 'date': '25/8/21'}
# {'avg_surface_temperature': None, 'date': '26/8/21'}
# {'avg_surface_temperature': None, 'date': '27/8/21'}
# {'avg_surface_temperature': None, 'date': '28/8/21'}
# {'avg_surface_temperature': None, 'date': '29/8/21'}
# {'avg_surface_temperature': None, 'date': '30/8/21'}
# {'avg_surface_temperature': None, 'date': '31/8/21'}
# {'avg_surface_temperature': None, 'date': '1/9/21'}
# {'avg_surface_temperature': None, 'date': '2/9/21'}
# {'avg_surface_temperature': None, 'date': '3/9/21'}
# {'avg_surface_temperature': None, 'date': '4/9/21'}
# {'avg_surface_temperature': None, 'date': '5/9/21'}
# {'avg_surface_temperature': None, 'date': '6/9/21'}
# {'avg_surface_temperature': None, 'date': '7/9/21'}
# {'avg_surface_temperature': None, 'date': '8/9/21'}
# {'avg_surface_temperature': None, 'date': '9/9/21'}
# {'avg_surface_temperature': 56.5, 'date': '10/9/21'}
# {'avg_surface_temperature': None, 'date': '11/9/21'}
# {'avg_surface_temperature': None, 'date': '12/9/21'}
# {'avg_surface_temperature': None, 'date': '13/9/21'}
# {'avg_surface_temperature': None, 'date': '14/9/21'}
# {'avg_surface_temperature': None, 'date': '15/9/21'}
# {'avg_surface_temperature': None, 'date': '16/9/21'}
# {'avg_surface_temperature': None, 'date': '17/9/21'}
# {'avg_surface_temperature': None, 'date': '18/9/21'}
# {'avg_surface_temperature': None, 'date': '19/9/21'}
# {'avg_surface_temperature': 63.6, 'date': '20/9/21'}
# {'avg_surface_temperature': 40.5, 'date': '21/9/21'}
# {'avg_surface_temperature': 45.0, 'date': '22/9/21'}
# {'avg_surface_temperature': 52.73913043478261, 'date': '23/9/21'}
# {'avg_surface_temperature': 53.57142857142857, 'date': '24/9/21'}
# {'avg_surface_temperature': None, 'date': '25/9/21'}
# {'avg_surface_temperature': 33.0, 'date': '26/9/21'}
# {'avg_surface_temperature': 49.714285714285715, 'date': '27/9/21'}
# {'avg_surface_temperature': None, 'date': '28/9/21'}
# {'avg_surface_temperature': 43.0, 'date': '29/9/21'}
# {'avg_surface_temperature': None, 'date': '30/9/21'}
# {'avg_surface_temperature': 48.25, 'date': '1/10/21'}
# {'avg_surface_temperature': 43.57142857142857, 'date': '2/10/21'}
# {'avg_surface_temperature': 50.0, 'date': '3/10/21'}
# {'avg_surface_temperature': 49.0, 'date': '4/10/21'}
# {'avg_surface_temperature': None, 'date': '5/10/21'}
# {'avg_surface_temperature': 44.0, 'date': '6/10/21'}
# {'avg_surface_temperature': 42.0, 'date': '7/10/21'}
# {'avg_surface_temperature': 41.0, 'date': '8/10/21'}
# {'avg_surface_temperature': 44.0, 'date': '9/10/21'}
# {'avg_surface_temperature': 53.333333333333336, 'date': '10/10/21'}
# {'avg_surface_temperature': None, 'date': '11/10/21'}
# {'avg_surface_temperature': None, 'date': '12/10/21'}
# {'avg_surface_temperature': None, 'date': '13/10/21'}
# {'avg_surface_temperature': None, 'date': '14/10/21'}
# {'avg_surface_temperature': 72.66666666666667, 'date': '15/10/21'}
# {'avg_surface_temperature': 36.0, 'date': '16/10/21'}
# {'avg_surface_temperature': 51.6, 'date': '17/10/21'}
# {'avg_surface_temperature': 52.166666666666664, 'date': '18/10/21'}
# {'avg_surface_temperature': None, 'date': '19/10/21'}
# {'avg_surface_temperature': 50.0, 'date': '20/10/21'}
# {'avg_surface_temperature': 51.25, 'date': '21/10/21'}
# {'avg_surface_temperature': None, 'date': '22/10/21'}
# {'avg_surface_temperature': 38.0, 'date': '23/10/21'}
# {'avg_surface_temperature': None, 'date': '24/10/21'}
# {'avg_surface_temperature': None, 'date': '25/10/21'}
# {'avg_surface_temperature': 44.6, 'date': '26/10/21'}
# {'avg_surface_temperature': 50.4, 'date': '27/10/21'}
# {'avg_surface_temperature': 56.0, 'date': '28/10/21'}
# {'avg_surface_temperature': None, 'date': '29/10/21'}
# {'avg_surface_temperature': None, 'date': '30/10/21'}
# {'avg_surface_temperature': None, 'date': '31/10/21'}
# {'avg_surface_temperature': None, 'date': '1/11/21'}
# {'avg_surface_temperature': None, 'date': '2/11/21'}
# {'avg_surface_temperature': None, 'date': '3/11/21'}
# {'avg_surface_temperature': None, 'date': '4/11/21'}
# {'avg_surface_temperature': 58.5, 'date': '5/11/21'}
# {'avg_surface_temperature': None, 'date': '6/11/21'}
# {'avg_surface_temperature': None, 'date': '7/11/21'}
# {'avg_surface_temperature': 45.5, 'date': '8/11/21'}
# {'avg_surface_temperature': 61.3, 'date': '9/11/21'}
# {'avg_surface_temperature': None, 'date': '10/11/21'}
# {'avg_surface_temperature': 46.25, 'date': '11/11/21'}
# {'avg_surface_temperature': 53.0, 'date': '12/11/21'}
# {'avg_surface_temperature': 47.0, 'date': '13/11/21'}
# {'avg_surface_temperature': 52.0, 'date': '14/11/21'}
# {'avg_surface_temperature': None, 'date': '15/11/21'}
# {'avg_surface_temperature': None, 'date': '16/11/21'}
# {'avg_surface_temperature': None, 'date': '17/11/21'}
# {'avg_surface_temperature': None, 'date': '18/11/21'}
# {'avg_surface_temperature': None, 'date': '19/11/21'}
# {'avg_surface_temperature': None, 'date': '20/11/21'}
# {'avg_surface_temperature': 59.0, 'date': '21/11/21'}
# {'avg_surface_temperature': 61.5, 'date': '22/11/21'}
# {'avg_surface_temperature': 58.8, 'date': '23/11/21'}
# {'avg_surface_temperature': None, 'date': '24/11/21'}
# {'avg_surface_temperature': None, 'date': '25/11/21'}
# {'avg_surface_temperature': None, 'date': '26/11/21'}
# {'avg_surface_temperature': None, 'date': '27/11/21'}
# {'avg_surface_temperature': 42.0, 'date': '28/11/21'}
# {'avg_surface_temperature': 60.625, 'date': '29/11/21'}
# {'avg_surface_temperature': 52.41935483870968, 'date': '30/11/21'}
# {'avg_surface_temperature': None, 'date': '1/12/21'}
# {'avg_surface_temperature': None, 'date': '2/12/21'}
# {'avg_surface_temperature': None, 'date': '3/12/21'}
# {'avg_surface_temperature': None, 'date': '4/12/21'}
# {'avg_surface_temperature': None, 'date': '5/12/21'}
# {'avg_surface_temperature': None, 'date': '6/12/21'}
# {'avg_surface_temperature': None, 'date': '7/12/21'}
# {'avg_surface_temperature': 50.6, 'date': '8/12/21'}
# {'avg_surface_temperature': 58.25, 'date': '9/12/21'}
# {'avg_surface_temperature': 46.0, 'date': '10/12/21'}
# {'avg_surface_temperature': None, 'date': '11/12/21'}
# {'avg_surface_temperature': 44.0, 'date': '12/12/21'}
# {'avg_surface_temperature': 60.0, 'date': '13/12/21'}
# {'avg_surface_temperature': 70.0, 'date': '14/12/21'}
# {'avg_surface_temperature': 39.0, 'date': '15/12/21'}
# {'avg_surface_temperature': 57.8, 'date': '16/12/21'}
# {'avg_surface_temperature': None, 'date': '17/12/21'}
# {'avg_surface_temperature': None, 'date': '18/12/21'}
# {'avg_surface_temperature': None, 'date': '19/12/21'}
# {'avg_surface_temperature': None, 'date': '20/12/21'}
# {'avg_surface_temperature': 46.0, 'date': '21/12/21'}
# {'avg_surface_temperature': None, 'date': '22/12/21'}
# {'avg_surface_temperature': None, 'date': '23/12/21'}
# {'avg_surface_temperature': 32.0, 'date': '24/12/21'}
# {'avg_surface_temperature': 54.0, 'date': '25/12/21'}
# {'avg_surface_temperature': None, 'date': '26/12/21'}
# {'avg_surface_temperature': 62.75, 'date': '27/12/21'}
# {'avg_surface_temperature': None, 'date': '28/12/21'}
# {'avg_surface_temperature': None, 'date': '29/12/21'}
# {'avg_surface_temperature': None, 'date': '30/12/21'}
# {'avg_surface_temperature': None, 'date': '31/12/21'}
# {'avg_surface_temperature': None, 'date': '1/1/21'}

# %%
# i. Find the top 10 records with the lowest GHI.
cursor = collection.aggregate([
    {
        "$sort":{"GHI_w/m2":1}
    },
    {
        "$limit":10
    }
])
print_document(cursor)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('628cf69e2c4f13d2a9759015'),
#  'air_temperature_celcius': 5,
#  'cause_of_fire': 'other',
#  'date': '2/8/21',
#  'hotspot': [{'confidence': 94,
#               'datetime': '2021-08-02T03:45:40',
#               'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celcius': 87},
#              {'confidence': 54,
#               'datetime': '2021-08-02T03:45:00',
#               'latitude': -37.491,
#               'longitude': 141.936,
#               'surface_temperature_celcius': 40}],
#  'max_wind_speed': 5.1,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 38.6,
#  'station': '948701',
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('628cf69e2c4f13d2a9758ff4'),
#  'air_temperature_celcius': 5,
#  'cause_of_fire': 'other',
#  'date': '30/6/21',
#  'hotspot': [{'confidence': 78,
#               'datetime': '2021-06-30T04:41:25',
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44},
#              {'confidence': 78,
#               'datetime': '2021-06-30T04:41:25',
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44},
#              {'confidence': 81,
#               'datetime': '2021-06-30T00:27:19',
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48},
#              {'confidence': 75,
#               'datetime': '2021-06-30T00:27:19',
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 75,
#               'datetime': '2021-06-30T00:27:19',
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 81,
#               'datetime': '2021-06-30T00:27:19',
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'A',
#  'precipitation_value': 0.0,
#  'relative_humidity': 34.9,
#  'station': '948701',
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('628cf69e2c4f13d2a9758ff5'),
#  'air_temperature_celcius': 5,
#  'cause_of_fire': 'other',
#  'date': '1/7/21',
#  'hotspot': [{'confidence': 53,
#               'datetime': '2021-07-01T13:11:41',
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29},
#              {'confidence': 53,
#               'datetime': '2021-07-01T13:11:41',
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29},
#              {'confidence': 61,
#               'datetime': '2021-07-01T03:46:08',
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32},
#              {'confidence': 61,
#               'datetime': '2021-07-01T03:46:08',
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32}],
#  'max_wind_speed': 14.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 33.1,
#  'station': '948701',
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('628cf69e2c4f13d2a9758fff'),
#  'air_temperature_celcius': 6,
#  'date': '11/7/21',
#  'max_wind_speed': 5.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 39.0,
#  'station': '948701',
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('628cf69e2c4f13d2a9759003'),
#  'air_temperature_celcius': 6,
#  'date': '15/7/21',
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 37.1,
#  'station': '948701',
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('628cf69e2c4f13d2a9758ff6'),
#  'air_temperature_celcius': 6,
#  'cause_of_fire': 'other',
#  'date': '2/7/21',
#  'hotspot': [{'confidence': 84,
#               'datetime': '2021-07-02T04:29:18',
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52},
#              {'confidence': 84,
#               'datetime': '2021-07-02T04:29:18',
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52},
#              {'confidence': 69,
#               'datetime': '2021-07-02T04:29:10',
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 69,
#               'datetime': '2021-07-02T04:29:10',
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 88,
#               'datetime': '2021-07-02T04:29:00',
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 88,
#               'datetime': '2021-07-02T04:29:00',
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 50,
#               'datetime': '2021-07-02T04:28:42',
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28},
#              {'confidence': 50,
#               'datetime': '2021-07-02T04:28:42',
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28}],
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 30.8,
#  'station': '948701',
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628cf69e2c4f13d2a9759014'),
#  'air_temperature_celcius': 7,
#  'cause_of_fire': 'other',
#  'date': '1/8/21',
#  'hotspot': [{'confidence': 89,
#               'datetime': '2021-08-01T00:20:30',
#               'latitude': -38.3998,
#               'longitude': 147.064,
#               'surface_temperature_celcius': 65},
#              {'confidence': 78,
#               'datetime': '2021-08-01T00:19:30',
#               'latitude': -38.3982,
#               'longitude': 147.0509,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 7.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 40.7,
#  'station': '948701',
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628cf69e2c4f13d2a9759008'),
#  'air_temperature_celcius': 7,
#  'date': '20/7/21',
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.12,
#  'relative_humidity': 40.5,
#  'station': '948701',
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('628cf69e2c4f13d2a9759013'),
#  'air_temperature_celcius': 7,
#  'cause_of_fire': 'other',
#  'date': '31/7/21',
#  'hotspot': [{'confidence': 100,
#               'datetime': '2021-07-31T13:21:00',
#               'latitude': -37.8641,
#               'longitude': 143.4276,
#               'surface_temperature_celcius': 51},
#              {'confidence': 92,
#               'datetime': '2021-07-31T13:21:00',
#               'latitude': -37.8658,
#               'longitude': 143.4162,
#               'surface_temperature_celcius': 43}],
#  'max_wind_speed': 8.0,
#  'precipitation_flag': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 40.5,
#  'station': '948701',
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('628cf69e2c4f13d2a9759026'),
#  'air_temperature_celcius': 7,
#  'date': '19/8/21',
#  'max_wind_speed': 9.9,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.04,
#  'relative_humidity': 37.9,
#  'station': '948702',
#  'windspeed_knots': 5.7}

# %%
# j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35
cursor = collection.find(
    {
        "$and":[{"precipitation_flag":"G"},{"precipitation_value":{"$gte":0.20,"$lte":0.35}}]
    }, 
    {
        "_id": 0    
    }
)
print_document(cursor)
# Out:
# {'GHI_w/m2': 157,
#  'air_temperature_celcius': 19,
#  'date': '13/1/21',
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 54.1,
#  'station': '948700',
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  'air_temperature_celcius': 17,
#  'cause_of_fire': 'other',
#  'date': '29/3/21',
#  'hotspot': [{'confidence': 69,
#               'datetime': '2021-03-29T00:48:40',
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 49.9,
#  'station': '948701',
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  'air_temperature_celcius': 20,
#  'cause_of_fire': 'other',
#  'date': '20/4/21',
#  'hotspot': [{'confidence': 84,
#               'datetime': '2021-04-20T04:44:20',
#               'latitude': -36.8871,
#               'longitude': 145.1536,
#               'surface_temperature_celcius': 58},
#              {'confidence': 59,
#               'datetime': '2021-04-20T04:36:00',
#               'latitude': -38.4685,
#               'longitude': 146.673,
#               'surface_temperature_celcius': 40},
#              {'confidence': 60,
#               'datetime': '2021-04-20T04:34:10',
#               'latitude': -36.8922,
#               'longitude': 145.1252,
#               'surface_temperature_celcius': 40},
#              {'confidence': 93,
#               'datetime': '2021-04-20T04:34:10',
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72},
#              {'confidence': 77,
#               'datetime': '2021-04-20T04:33:40',
#               'latitude': -36.0799,
#               'longitude': 146.0784,
#               'surface_temperature_celcius': 50},
#              {'confidence': 88,
#               'datetime': '2021-04-20T04:33:20',
#               'latitude': -36.0829,
#               'longitude': 146.0621,
#               'surface_temperature_celcius': 63},
#              {'confidence': 90,
#               'datetime': '2021-04-20T04:32:50',
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67},
#              {'confidence': 67,
#               'datetime': '2021-04-20T04:32:50',
#               'latitude': -37.7615,
#               'longitude': 147.9169,
#               'surface_temperature_celcius': 45},
#              {'confidence': 63,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -36.8079,
#               'longitude': 145.1409,
#               'surface_temperature_celcius': 42},
#              {'confidence': 85,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -37.7783,
#               'longitude': 147.9284,
#               'surface_temperature_celcius': 60},
#              {'confidence': 79,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -36.8846,
#               'longitude': 145.1679,
#               'surface_temperature_celcius': 52},
#              {'confidence': 80,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -37.2341,
#               'longitude': 149.1736,
#               'surface_temperature_celcius': 53},
#              {'confidence': 63,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -36.9189,
#               'longitude': 147.5603,
#               'surface_temperature_celcius': 52},
#              {'confidence': 98,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84},
#              {'confidence': 87,
#               'datetime': '2021-04-20T04:32:30',
#               'latitude': -36.9246,
#               'longitude': 147.5559,
#               'surface_temperature_celcius': 62},
#              {'confidence': 64,
#               'datetime': '2021-04-20T00:19:00',
#               'latitude': -36.085,
#               'longitude': 145.9096,
#               'surface_temperature_celcius': 42},
#              {'confidence': 88,
#               'datetime': '2021-04-20T00:18:40',
#               'latitude': -38.1301,
#               'longitude': 143.9398,
#               'surface_temperature_celcius': 63},
#              {'confidence': 69,
#               'datetime': '2021-04-20T00:18:20',
#               'latitude': -37.7087,
#               'longitude': 145.5499,
#               'surface_temperature_celcius': 45},
#              {'confidence': 100,
#               'datetime': '2021-04-20T00:18:20',
#               'latitude': -36.5865,
#               'longitude': 145.2081,
#               'surface_temperature_celcius': 111},
#              {'confidence': 73,
#               'datetime': '2021-04-20T00:17:10',
#               'latitude': -36.8702,
#               'longitude': 144.0381,
#               'surface_temperature_celcius': 47},
#              {'confidence': 99,
#               'datetime': '2021-04-20T00:17:10',
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85},
#              {'confidence': 74,
#               'datetime': '2021-04-20T00:16:50',
#               'latitude': -37.8672,
#               'longitude': 143.8194,
#               'surface_temperature_celcius': 48},
#              {'confidence': 78,
#               'datetime': '2021-04-20T00:15:30',
#               'latitude': -36.5956,
#               'longitude': 145.206,
#               'surface_temperature_celcius': 51},
#              {'confidence': 77,
#               'datetime': '2021-04-20T00:14:20',
#               'latitude': -37.2197,
#               'longitude': 148.8134,
#               'surface_temperature_celcius': 50},
#              {'confidence': 96,
#               'datetime': '2021-04-20T00:14:10',
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78},
#              {'confidence': 89,
#               'datetime': '2021-04-20T00:13:40',
#               'latitude': -37.6997,
#               'longitude': 145.5519,
#               'surface_temperature_celcius': 64},
#              {'confidence': 61,
#               'datetime': '2021-04-20T00:13:30',
#               'latitude': -37.932,
#               'longitude': 146.1845,
#               'surface_temperature_celcius': 50},
#              {'confidence': 76,
#               'datetime': '2021-04-20T00:13:10',
#               'latitude': -36.6407,
#               'longitude': 144.2957,
#               'surface_temperature_celcius': 50},
#              {'confidence': 63,
#               'datetime': '2021-04-20T00:13:00',
#               'latitude': -36.1569,
#               'longitude': 145.6554,
#               'surface_temperature_celcius': 41},
#              {'confidence': 54,
#               'datetime': '2021-04-20T00:13:00',
#               'latitude': -36.6363,
#               'longitude': 144.3033,
#               'surface_temperature_celcius': 40},
#              {'confidence': 76,
#               'datetime': '2021-04-20T00:12:50',
#               'latitude': -37.2212,
#               'longitude': 148.8262,
#               'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 53.5,
#  'station': '948701',
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  'air_temperature_celcius': 11,
#  'cause_of_fire': 'other',
#  'date': '26/4/21',
#  'hotspot': [{'confidence': 56,
#               'datetime': '2021-04-26T13:26:10',
#               'latitude': -36.5511,
#               'longitude': 146.7819,
#               'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 40.8,
#  'station': '948701',
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  'air_temperature_celcius': 14,
#  'date': '27/5/21',
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.35,
#  'relative_humidity': 48.1,
#  'station': '948701',
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  'air_temperature_celcius': 8,
#  'date': '30/5/21',
#  'max_wind_speed': 15.9,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 41.6,
#  'station': '948701',
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  'air_temperature_celcius': 11,
#  'date': '3/7/21',
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 45.1,
#  'station': '948701',
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  'air_temperature_celcius': 11,
#  'date': '27/7/21',
#  'max_wind_speed': 21.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 43.5,
#  'station': '948701',
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  'air_temperature_celcius': 9,
#  'date': '6/8/21',
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 41.1,
#  'station': '948702',
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  'air_temperature_celcius': 11,
#  'date': '26/8/21',
#  'max_wind_speed': 19.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 39.7,
#  'station': '948702',
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  'air_temperature_celcius': 8,
#  'date': '5/9/21',
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 38.6,
#  'station': '948702',
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  'air_temperature_celcius': 10,
#  'date': '7/9/21',
#  'max_wind_speed': 14.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 43.6,
#  'station': '948702',
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  'air_temperature_celcius': 11,
#  'date': '15/9/21',
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 46.2,
#  'station': '948702',
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  'air_temperature_celcius': 12,
#  'date': '5/10/21',
#  'max_wind_speed': 18.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 47.5,
#  'station': '948702',
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  'air_temperature_celcius': 17,
#  'date': '29/10/21',
#  'max_wind_speed': 27.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 44.9,
#  'station': '948702',
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  'air_temperature_celcius': 11,
#  'date': '30/10/21',
#  'max_wind_speed': 14.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 43.2,
#  'station': '948702',
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 18,
#  'date': '16/11/21',
#  'max_wind_speed': 11.1,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 61.5,
#  'station': '948702',
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  'air_temperature_celcius': 19,
#  'date': '17/11/21',
#  'max_wind_speed': 12.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 58.7,
#  'station': '948702',
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'cause_of_fire': 'natural',
#  'date': '30/11/21',
#  'hotspot': [{'confidence': 52,
#               'datetime': '2021-11-30T23:25:57',
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47},
#              {'confidence': 100,
#               'datetime': '2021-11-30T15:38:36',
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#              {'confidence': 51,
#               'datetime': '2021-11-30T15:38:36',
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42},
#              {'confidence': 64,
#               'datetime': '2021-11-30T15:38:36',
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42},
#              {'confidence': 100,
#               'datetime': '2021-11-30T15:38:35',
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#              {'confidence': 69,
#               'datetime': '2021-11-30T15:38:35',
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35},
#              {'confidence': 100,
#               'datetime': '2021-11-30T15:38:35',
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#              {'confidence': 61,
#               'datetime': '2021-11-30T15:38:32',
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31},
#              {'confidence': 62,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33},
#              {'confidence': 64,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32},
#              {'confidence': 84,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#              {'confidence': 81,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#              {'confidence': 100,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#              {'confidence': 100,
#               'datetime': '2021-11-30T12:22:15',
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#              {'confidence': 100,
#               'datetime': '2021-11-30T12:22:14',
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#              {'confidence': 84,
#               'datetime': '2021-11-30T04:35:00',
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#              {'confidence': 73,
#               'datetime': '2021-11-30T04:35:00',
#               'latitude': -37.389,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 50},
#              {'confidence': 98,
#               'datetime': '2021-11-30T04:34:57',
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83},
#              {'confidence': 81,
#               'datetime': '2021-11-30T04:34:57',
#               'latitude': -37.627,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#              {'confidence': 84,
#               'datetime': '2021-11-30T04:34:57',
#               'latitude': -37.623,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#              {'confidence': 99,
#               'datetime': '2021-11-30T04:34:57',
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#              {'confidence': 69,
#               'datetime': '2021-11-30T04:34:57',
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48},
#              {'confidence': 60,
#               'datetime': '2021-11-30T00:21:00',
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42},
#              {'confidence': 83,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.608,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#              {'confidence': 87,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.62,
#               'longitude': 149.294,
#               'surface_temperature_celcius': 63},
#              {'confidence': 95,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#              {'confidence': 81,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#              {'confidence': 73,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.603,
#               'longitude': 149.324,
#               'surface_temperature_celcius': 51},
#              {'confidence': 81,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#              {'confidence': 69,
#               'datetime': '2021-11-30T00:20:53',
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50},
#              {'confidence': 64,
#               'datetime': '2021-11-30T00:20:49',
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation_flag': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 61.0,
#  'station': '948702',
#  'windspeed_knots': 9.3}
